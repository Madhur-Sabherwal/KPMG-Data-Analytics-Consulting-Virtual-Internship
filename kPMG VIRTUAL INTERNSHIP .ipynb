# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings 
import datetime

# %% [markdown]
# ## Working on Customer Demographics Data set

# %%
data1=pd.read_excel(r"KPMG_VI_New_raw_data_update_final.xlsx",sheet_name='CustomerDemographic')
data1.head(30)
# Out:
#     customer_id      first_name  last_name  gender  \
# 0             1         Laraine  Medendorp       F
# 1             2             Eli    Bockman    Male
# 2             3           Arlin     Dearle    Male
# 3             4          Talbot        NaN    Male
# 4             5  Sheila-kathryn     Calton  Female
# 5             6            Curr  Duckhouse    Male
# 6             7            Fina     Merali  Female
# 7             8             Rod      Inder    Male
# 8             9            Mala       Lind  Female
# 9            10        Fiorenze    Birdall  Female
# 10           11           Uriah     Bisatt    Male
# 11           12         Sawyere   Flattman    Male
# 12           13        Gabriele   Norcross    Male
# 13           14        Rayshell   Kitteman  Female
# 14           15          Erroll     Radage    Male
# 15           16          Harlin       Parr    Male
# 16           17           Heath    Faraday    Male
# ...

# %% [markdown]
# # some things i have observed
# customer_id : it is starting from 1 to the last
#
# first_name : it contain all the customers first name data
#
# last_name : it contain all the customers last name data
#
# gender : it contain gender name : here we need to see the data has problems since
# there are values which are either "f" instead of "female"
#
# past_3_years_bike_related_purchases : this represent number of purchases done in past 3 years
#
# dob: this represent the data of the date of birth
#
# job title : here it is written that the title of job : we need to careful here since there are some missing values.
#
# job_industry_category : The job industry category tells a lot about the person in which the person is working
#
# wealth segment : this tells us weather the person is in which wealth segment
#
# deceased indicator : its a yes or no always N here represent a no and Y here represent Yes
#
# default : it is the term we need to remove this columns.
#
# own_car : this is another yes or no answer.
#
# tenure : here this represent the time in the proffesion.

# %% [markdown]
# ## Task to do

# %% [markdown]
# fill gender with the same value
#
# fill missing values in the nan
#
# delete default
#
# put o and 1 in the car section

# %%
#deleting default column
del data1['default']

# %% [markdown]
# # fill gender with the same value.

# %%
data1['gender'] = data1['gender'].replace('F', 'Female')
data1['gender'] = data1['gender'].replace('M', 'Male')
data1['gender'] = data1['gender'].replace('U', 'Unknown')
data1
# Out:
#       customer_id      first_name      last_name   gender  \
# 0               1         Laraine      Medendorp   Female
# 1               2             Eli        Bockman     Male
# 2               3           Arlin         Dearle     Male
# 3               4          Talbot            NaN     Male
# 4               5  Sheila-kathryn         Calton   Female
# 5               6            Curr      Duckhouse     Male
# 6               7            Fina         Merali   Female
# 7               8             Rod          Inder     Male
# 8               9            Mala           Lind   Female
# 9              10        Fiorenze        Birdall   Female
# 10             11           Uriah         Bisatt     Male
# 11             12         Sawyere       Flattman     Male
# 12             13        Gabriele       Norcross     Male
# 13             14        Rayshell       Kitteman   Female
# 14             15          Erroll         Radage     Male
# ...

# %% [markdown]
# #HERE
#
#
# 1: FEMALE
#
# 2: MALE
#
# 3: UNKNOWN

# %%
data1 =data1.dropna()

# %%
data2=pd.read_excel(r"KPMG_VI_New_raw_data_update_final.xlsx",sheet_name='CustomerAddress')
data2.head(30)
# Out:
#     customer_id                  address  postcode            state  \
# 0             1       060 Morning Avenue      2016  New South Wales
# 1             2      6 Meadow Vale Court      2153  New South Wales
# 2             4       0 Holy Cross Court      4211              QLD
# 3             5      17979 Del Mar Point      2448  New South Wales
# 4             6         9 Oakridge Court      3216              VIC
# 5             7         4 Delaware Trail      2210  New South Wales
# 6             8      49 Londonderry Lane      2650  New South Wales
# 7             9          97736 7th Trail      2023  New South Wales
# 8            11     93405 Ludington Park      3044              VIC
# 9            12  44339 Golden Leaf Alley      4557              QLD
# 10           13      2 Sutherland Street      3799              VIC
# 11           14          9 Mcbride Trail      2760  New South Wales
# 12           15   9861 New Castle Avenue      2428  New South Wales
# ...

# %%
data2['state'] = data2['state'].replace('NSW', 'New South Wales')
data2['state'] = data2['state'].replace('QLD', 'Queensland')
data2['state'] = data2['state'].replace('VIC', 'Victoria')
data2
# Out:
#       customer_id                     address  postcode            state  \
# 0               1          060 Morning Avenue      2016  New South Wales
# 1               2         6 Meadow Vale Court      2153  New South Wales
# 2               4          0 Holy Cross Court      4211       Queensland
# 3               5         17979 Del Mar Point      2448  New South Wales
# 4               6            9 Oakridge Court      3216         Victoria
# 5               7            4 Delaware Trail      2210  New South Wales
# 6               8         49 Londonderry Lane      2650  New South Wales
# 7               9             97736 7th Trail      2023  New South Wales
# 8              11        93405 Ludington Park      3044         Victoria
# 9              12     44339 Golden Leaf Alley      4557       Queensland
# 10             13         2 Sutherland Street      3799         Victoria
# 11             14             9 Mcbride Trail      2760  New South Wales
# ...

# %%
data2.isnull().sum()
# Out:
# customer_id           0
# address               0
# postcode              0
# state                 0
# country               0
# property_valuation    0
# dtype: int64

# %%
data3=pd.read_excel(r"KPMG_VI_New_raw_data_update_final.xlsx",sheet_name='Transactions')
data3.head(30)
# Out:
#     transaction_id  product_id  customer_id transaction_date  online_order  \
# 0                1           2         2950       2017-02-25           0.0
# 1                2           3         3120       2017-05-21           1.0
# 2                3          37          402       2017-10-16           0.0
# 3                4          88         3135       2017-08-31           0.0
# 4                5          78          787       2017-10-01           1.0
# 5                6          25         2339       2017-03-08           1.0
# 6                7          22         1542       2017-04-21           1.0
# 7                8          15         2459       2017-07-15           0.0
# 8                9          67         1305       2017-08-10           0.0
# 9               10          12         3262       2017-08-30           1.0
# 10              11           5         1986       2017-01-17           0.0
# ...

# %%
data3.isnull().sum()
data3.dropna()
# Out:
#        transaction_id  product_id  customer_id transaction_date  online_order  \
# 0                   1           2         2950       2017-02-25           0.0
# 1                   2           3         3120       2017-05-21           1.0
# 2                   3          37          402       2017-10-16           0.0
# 3                   4          88         3135       2017-08-31           0.0
# 4                   5          78          787       2017-10-01           1.0
# 5                   6          25         2339       2017-03-08           1.0
# 6                   7          22         1542       2017-04-21           1.0
# 7                   8          15         2459       2017-07-15           0.0
# 8                   9          67         1305       2017-08-10           0.0
# 9                  10          12         3262       2017-08-30           1.0
# 10                 11           5         1986       2017-01-17           0.0
# ...

# %%
del data3['product_first_sold_date']

# %%
data3
# Out:
#        transaction_id  product_id  customer_id transaction_date  online_order  \
# 0                   1           2         2950       2017-02-25           0.0
# 1                   2           3         3120       2017-05-21           1.0
# 2                   3          37          402       2017-10-16           0.0
# 3                   4          88         3135       2017-08-31           0.0
# 4                   5          78          787       2017-10-01           1.0
# 5                   6          25         2339       2017-03-08           1.0
# 6                   7          22         1542       2017-04-21           1.0
# 7                   8          15         2459       2017-07-15           0.0
# 8                   9          67         1305       2017-08-10           0.0
# 9                  10          12         3262       2017-08-30           1.0
# 10                 11           5         1986       2017-01-17           0.0
# ...

# %%
data4=pd.read_excel(r"KPMG_VI_New_raw_data_update_final.xlsx",sheet_name='NewCustomerList')
data4.head(30)
# Out:
#    first_name     last_name  gender  past_3_years_bike_related_purchases  \
# 0     Chickie       Brister    Male                                   86
# 1       Morly        Genery    Male                                   69
# 2     Ardelis     Forrester  Female                                   10
# 3      Lucine         Stutt  Female                                   64
# 4     Melinda        Hadlee  Female                                   34
# 5       Druci       Brandli  Female                                   39
# 6    Rutledge         Hallt    Male                                   23
# 7      Nancie          Vian  Female                                   74
# 8        Duff     Karlowicz    Male                                   50
# 9     Barthel        Docket    Male                                   72
# 10   Rockwell        Matson    Male                                   94
# 11    Wheeler       Winward    Male                                   48
# ...

# %%
del data4['Unnamed: 16']

# %%
del data4['Unnamed: 17']
del data4['Unnamed: 18']
del data4['Unnamed: 19']
del data4['Unnamed: 20']

# %%
data4
# Out:
#     first_name     last_name  gender  past_3_years_bike_related_purchases  \
# 0      Chickie       Brister    Male                                   86
# 1        Morly        Genery    Male                                   69
# 2      Ardelis     Forrester  Female                                   10
# 3       Lucine         Stutt  Female                                   64
# 4      Melinda        Hadlee  Female                                   34
# 5        Druci       Brandli  Female                                   39
# 6     Rutledge         Hallt    Male                                   23
# 7       Nancie          Vian  Female                                   74
# 8         Duff     Karlowicz    Male                                   50
# 9      Barthel        Docket    Male                                   72
# 10    Rockwell        Matson    Male                                   94
# 11     Wheeler       Winward    Male                                   48
# ...

# %%
#converting own_car varible from categorical into numerical 
#label_encoding the data 
from sklearn.preprocessing import LabelEncoder
labelencoder = LabelEncoder()
data4['owns_car']= labelencoder.fit_transform(data4['owns_car'])
data1
# Out:
#       customer_id  first_name      last_name   gender  \
# 0               1     Laraine      Medendorp   Female
# 1               2         Eli        Bockman     Male
# 2               3       Arlin         Dearle     Male
# 8               9        Mala           Lind   Female
# 9              10    Fiorenze        Birdall   Female
# 11             12     Sawyere       Flattman     Male
# 12             13    Gabriele       Norcross     Male
# 13             14    Rayshell       Kitteman   Female
# 14             15      Erroll         Radage     Male
# 18             19      Sorcha         Keyson   Female
# 19             20      Basile          Firth     Male
# 20             21        Mile       Cammocke     Male
# 23             24         Kim         Skpsey   Female
# 24             25       Geoff          Assaf     Male
# 25             26       Trixi       Ginnelly   Female
# 26             27      Garvin          Klees     Male
# ...

# %%
data4['gender'] = data4['gender'].replace('F', 'Female')
data4['gender'] = data4['gender'].replace('M', 'Male')
data4['gender'] = data4['gender'].replace('U', 'Unknown')
data4
# Out:
#     first_name     last_name   gender  past_3_years_bike_related_purchases  \
# 0      Chickie       Brister     Male                                   86
# 1        Morly        Genery     Male                                   69
# 2      Ardelis     Forrester   Female                                   10
# 3       Lucine         Stutt   Female                                   64
# 4      Melinda        Hadlee   Female                                   34
# 5        Druci       Brandli   Female                                   39
# 6     Rutledge         Hallt     Male                                   23
# 7       Nancie          Vian   Female                                   74
# 8         Duff     Karlowicz     Male                                   50
# 9      Barthel        Docket     Male                                   72
# 10    Rockwell        Matson     Male                                   94
# ...

# %%
data4 =data4.dropna()

# %%
data4
# Out:
#      first_name     last_name  gender  past_3_years_bike_related_purchases  \
# 0       Chickie       Brister    Male                                   86
# 1         Morly        Genery    Male                                   69
# 2       Ardelis     Forrester  Female                                   10
# 3        Lucine         Stutt  Female                                   64
# 4       Melinda        Hadlee  Female                                   34
# 5         Druci       Brandli  Female                                   39
# 6      Rutledge         Hallt    Male                                   23
# 7        Nancie          Vian  Female                                   74
# 8          Duff     Karlowicz    Male                                   50
# 9       Barthel        Docket    Male                                   72
# 10     Rockwell        Matson    Male                                   94
# ...

# %% [markdown]
# ## Data is cleaned

# %% [markdown]
# # Data preprocessing

# %%
data1.dtypes
# Out:
# customer_id                                     int64
# first_name                                     object
# last_name                                      object
# gender                                         object
# past_3_years_bike_related_purchases             int64
# DOB                                    datetime64[ns]
# job_title                                      object
# job_industry_category                          object
# wealth_segment                                 object
# deceased_indicator                             object
# owns_car                                       object
# tenure                                        float64
# dtype: object

# %%
data1dict = ({'customer_id': int, 'first_name': str,
              'past_3_years_bike_related_purchases': int, 'job_title': str,'wealth_segment': str})

# %%
data1 = data1.astype(data1dict)

# %%
data1
# Out:
#       customer_id  first_name      last_name   gender  \
# 0               1     Laraine      Medendorp   Female
# 1               2         Eli        Bockman     Male
# 2               3       Arlin         Dearle     Male
# 8               9        Mala           Lind   Female
# 9              10    Fiorenze        Birdall   Female
# 11             12     Sawyere       Flattman     Male
# 12             13    Gabriele       Norcross     Male
# 13             14    Rayshell       Kitteman   Female
# 14             15      Erroll         Radage     Male
# 18             19      Sorcha         Keyson   Female
# 19             20      Basile          Firth     Male
# 20             21        Mile       Cammocke     Male
# 23             24         Kim         Skpsey   Female
# 24             25       Geoff          Assaf     Male
# 25             26       Trixi       Ginnelly   Female
# 26             27      Garvin          Klees     Male
# ...

# %%
data2.dtypes
# Out:
# customer_id            int64
# address               object
# postcode               int64
# state                 object
# country               object
# property_valuation     int64
# dtype: object

# %%
data2dict = ({'customer_id': int, 'address': str,'postcode': int
              ,'state': str, 'country': str,'property_valuation': int})

# %%
data2 = data2.astype(data2dict)

# %%
data2.dtypes
# Out:
# customer_id            int32
# address               object
# postcode               int32
# state                 object
# country               object
# property_valuation     int32
# dtype: object

# %%
data2
# Out:
#       customer_id                     address  postcode            state  \
# 0               1          060 Morning Avenue      2016  New South Wales
# 1               2         6 Meadow Vale Court      2153  New South Wales
# 2               4          0 Holy Cross Court      4211       Queensland
# 3               5         17979 Del Mar Point      2448  New South Wales
# 4               6            9 Oakridge Court      3216         Victoria
# 5               7            4 Delaware Trail      2210  New South Wales
# 6               8         49 Londonderry Lane      2650  New South Wales
# 7               9             97736 7th Trail      2023  New South Wales
# 8              11        93405 Ludington Park      3044         Victoria
# 9              12     44339 Golden Leaf Alley      4557       Queensland
# 10             13         2 Sutherland Street      3799         Victoria
# 11             14             9 Mcbride Trail      2760  New South Wales
# ...

# %%
data3
# Out:
#        transaction_id  product_id  customer_id transaction_date  online_order  \
# 0                   1           2         2950       2017-02-25           0.0
# 1                   2           3         3120       2017-05-21           1.0
# 2                   3          37          402       2017-10-16           0.0
# 3                   4          88         3135       2017-08-31           0.0
# 4                   5          78          787       2017-10-01           1.0
# 5                   6          25         2339       2017-03-08           1.0
# 6                   7          22         1542       2017-04-21           1.0
# 7                   8          15         2459       2017-07-15           0.0
# 8                   9          67         1305       2017-08-10           0.0
# 9                  10          12         3262       2017-08-30           1.0
# 10                 11           5         1986       2017-01-17           0.0
# ...

# %%
data3.dtypes
# Out:
# transaction_id               int64
# product_id                   int64
# customer_id                  int64
# transaction_date    datetime64[ns]
# online_order               float64
# order_status                object
# brand                       object
# product_line                object
# product_class               object
# product_size                object
# list_price                 float64
# standard_cost              float64
# dtype: object

# %%
data4.dtypes
# Out:
# first_name                                     object
# last_name                                      object
# gender                                         object
# past_3_years_bike_related_purchases             int64
# DOB                                    datetime64[ns]
# job_title                                      object
# job_industry_category                          object
# wealth_segment                                 object
# deceased_indicator                             object
# owns_car                                        int32
# tenure                                          int64
# address                                        object
# postcode                                        int64
# state                                          object
# country                                        object
# property_valuation                              int64
# Rank                                            int64
# ...

# %%
data4dict = ({'first_name': str, 'last_name': str,'past_3_years_bike_related_purchases': int, 'job_title': str,'job_industry_category': str,'wealth_segment': str, 'owns_car': int,'tenure': int})

# %%
data4= data4.astype(data4dict)

# %%
data4
# Out:
#      first_name     last_name  gender  past_3_years_bike_related_purchases  \
# 0       Chickie       Brister    Male                                   86
# 1         Morly        Genery    Male                                   69
# 2       Ardelis     Forrester  Female                                   10
# 3        Lucine         Stutt  Female                                   64
# 4       Melinda        Hadlee  Female                                   34
# 5         Druci       Brandli  Female                                   39
# 6      Rutledge         Hallt    Male                                   23
# 7        Nancie          Vian  Female                                   74
# 8          Duff     Karlowicz    Male                                   50
# 9       Barthel        Docket    Male                                   72
# 10     Rockwell        Matson    Male                                   94
# ...

# %% [markdown]
# ## Now we will check common columns and join the dataset for further approach
#
# Data 1 : customer demographics
#
# Data 2 : Customer address
#
# Data 3 : Transactions
#
# Data 4 : NewCustomerList

# %%
data1.head(2)
# Out:
#    customer_id first_name  last_name  gender  \
# 0            1    Laraine  Medendorp  Female
# 1            2        Eli    Bockman    Male
#
#    past_3_years_bike_related_purchases        DOB               job_title  \
# 0                                   93 1953-10-12     Executive Secretary
# 1                                   81 1980-12-16  Administrative Officer
#
#   job_industry_category wealth_segment deceased_indicator owns_car  tenure
# 0                Health  Mass Customer                  N      Yes    11.0
# 1    Financial Services  Mass Customer                  N      Yes    16.0

# %%
data2.head(2)
# Out:
#    customer_id              address  postcode            state    country  \
# 0            1   060 Morning Avenue      2016  New South Wales  Australia
# 1            2  6 Meadow Vale Court      2153  New South Wales  Australia
#
#    property_valuation
# 0                  10
# 1                  10

# %%
data3.head(2)
# Out:
#    transaction_id  product_id  customer_id transaction_date  online_order  \
# 0               1           2         2950       2017-02-25           0.0
# 1               2           3         3120       2017-05-21           1.0
#
#   order_status          brand product_line product_class product_size  \
# 0     Approved          Solex     Standard        medium       medium
# 1     Approved  Trek Bicycles     Standard        medium        large
#
#    list_price  standard_cost
# 0       71.49          53.62
# 1     2091.47         388.92

# %%
data4.head(2)
# Out:
#   first_name last_name gender  past_3_years_bike_related_purchases        DOB  \
# 0    Chickie   Brister   Male                                   86 1957-07-12
# 1      Morly    Genery   Male                                   69 1970-03-22
#
#              job_title job_industry_category wealth_segment  \
# 0      General Manager         Manufacturing  Mass Customer
# 1  Structural Engineer              Property  Mass Customer
#
#   deceased_indicator  owns_car  tenure            address  postcode state  \
# 0                  N         1      14   45 Shopko Center      4500   QLD
# 1                  N         0      16  14 Mccormick Park      2113   NSW
#
#      country  property_valuation  Rank    Value
# 0  Australia                   6     1  1.71875
# 1  Australia                  11     1  1.71875

# %%
print ("The shape of the  data having information of customer demographics is ",data1.shape)
print ("The shape of the  data having information of customer Address is ",data2.shape)
print ("The shape of the  data having information of customer Transaction is ",data3.shape)
print ("The shape of the  data having information of customer NewCustomerList is ",data4.shape)
# Out:
# The shape of the  data having information of customer demographics is  (2780, 12)
# The shape of the  data having information of customer Address is  (3999, 6)
# The shape of the  data having information of customer Transaction is  (20000, 12)
# The shape of the  data having information of customer NewCustomerList is  (715, 18)

# %% [markdown]
# ## Joining the dataframes of Customer Demographics, Customer Address, Customer Transcation.

# %%
NewData = pd.merge(data1,data2,on='customer_id', how = 'inner')

# %%
NewData.shape
# Out:
# (2778, 17)

# %%
NewData1 = pd.merge(NewData,data3,on='customer_id', how = 'inner')

# %%
NewData1.shape
# Out:
# (14011, 28)

# %%
NewData1 = NewData1.drop_duplicates()
NewData1['Name'] = NewData1['first_name']+ ' ' +NewData1['last_name']

# %% [markdown]
# # Data exploration and visulisation

# %%
bar_graph1= plt.bar(NewData1.state.unique(), NewData1["state"].value_counts())

bar_graph1[0].set_color('#FF5F6D')
bar_graph1[1].set_color('#19547b')
bar_graph1[2].set_color('#6A82FB')

plt.ylabel('Number of Customer', color='g')
plt.xlabel('State', color='r')
plt.title("Customer vs State")
plt.show()

# %%
bar_graph2 = plt.bar(NewData1.gender.unique(), NewData1["gender"].value_counts() )

bar_graph2[0].set_color('#FF5F6D')
bar_graph2[1].set_color('#19547b')

plt.ylabel('Number of Customer', color ='g')
plt.xlabel('Gender', color='r')
plt.title("Customer vs Gender")
plt.show()

# %%
bar_graph3 = plt.bar(NewData1.owns_car.unique(), NewData1["owns_car"].value_counts())

bar_graph3[0].set_color('#00c3ff')
bar_graph3[1].set_color('#f7797d')

plt.ylabel('Customer who owns car?', color ='g')
plt.xlabel('Yes / No', color='r')
plt.show()

# %%
bar_graph4 = plt.bar(NewData1.wealth_segment.unique(), NewData1["wealth_segment"].value_counts())

bar_graph4[0].set_color('#FF5F9D')
bar_graph4[1].set_color('#c471ed')
bar_graph4[2].set_color('#2193b0')

plt.ylabel('Number of customer', color='g')
plt.xlabel('Wealth Segment', color='r')
plt.title("No. of Customer vs Wealth Segment")
plt.show()

# %%
results1 = NewData1.groupby("gender").sum()
bar_graph5 = plt.bar(NewData1.gender.unique(), results1["past_3_years_bike_related_purchases"])

bar_graph5[0].set_color('#FF5F6D')
bar_graph5[1].set_color('#19547b')

plt.ylabel('Past 3(yrs) bike related purchases', color='g')
plt.xlabel('Gender', color='r')
plt.title("Past 3(yrs) bike related purchase vs Gender")
plt.show()

# %%
sns.countplot(x='job_industry_category', data=NewData1, palette='hls')
plt.xticks(rotation ='vertical')
plt.show()

# %% [markdown]
# # Model Building
